# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
inc_data = pd.read_csv(r"C:\Users\mayur\Downloads\Inc_Exp_Data.csv")
inc_data.head()
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             5000              8000                  3             2000
# 1             6000              7000                  2             3000
# 2            10000              4500                  2                0
# 3            10000              2000                  1                0
# 4            12500             12000                  2             3000
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0             64200           Under-Graduate                      1
# 1             79920               Illiterate                      1
# 2            112800           Under-Graduate                      1
# 3             97200               Illiterate                      1
# 4            147000                 Graduate                      1

# %%
inc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Mthly_HH_Income           50 non-null     int64
#  1   Mthly_HH_Expense          50 non-null     int64
#  2   No_of_Fly_Members         50 non-null     int64
#  3   Emi_or_Rent_Amt           50 non-null     int64
#  4   Annual_HH_Income          50 non-null     int64
#  5   Highest_Qualified_Member  50 non-null     object
#  6   No_of_Earning_Members     50 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.9+ KB

# %%
inc_data.shape
# Out:
# (50, 7)

# %%
inc_data.columns
# Out:
# Index(['Mthly_HH_Income', 'Mthly_HH_Expense', 'No_of_Fly_Members',
#        'Emi_or_Rent_Amt', 'Annual_HH_Income', 'Highest_Qualified_Member',
#        'No_of_Earning_Members'],
#       dtype='object')

# %%
len(inc_data.columns)
# Out:
# 7

# %%
inc_data.describe()
# Out:
#        Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# count        50.000000         50.000000          50.000000        50.000000
# mean      41558.000000      18818.000000           4.060000      3060.000000
# std       26097.908979      12090.216824           1.517382      6241.434948
# min        5000.000000       2000.000000           1.000000         0.000000
# 25%       23550.000000      10000.000000           3.000000         0.000000
# 50%       35000.000000      15500.000000           4.000000         0.000000
# 75%       50375.000000      25000.000000           5.000000      3500.000000
# max      100000.000000      50000.000000           7.000000     35000.000000
#
#        Annual_HH_Income  No_of_Earning_Members
# count      5.000000e+01              50.000000
# mean       4.900190e+05               1.460000
# std        3.201358e+05               0.734291
# min        6.420000e+04               1.000000
# ...

# %%
inc_data.isna()
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             False             False              False            False
# 1             False             False              False            False
# 2             False             False              False            False
# 3             False             False              False            False
# 4             False             False              False            False
# 5             False             False              False            False
# 6             False             False              False            False
# 7             False             False              False            False
# 8             False             False              False            False
# 9             False             False              False            False
# 10            False             False              False            False
# 11            False             False              False            False
# ...

# %%
inc_data.isna().sum()
# Out:
# Mthly_HH_Income             0
# Mthly_HH_Expense            0
# No_of_Fly_Members           0
# Emi_or_Rent_Amt             0
# Annual_HH_Income            0
# Highest_Qualified_Member    0
# No_of_Earning_Members       0
# dtype: int64

# %%
inc_data.isna().any()
# Out:
# Mthly_HH_Income             False
# Mthly_HH_Expense            False
# No_of_Fly_Members           False
# Emi_or_Rent_Amt             False
# Annual_HH_Income            False
# Highest_Qualified_Member    False
# No_of_Earning_Members       False
# dtype: bool

# %%
inc_data['Mthly_HH_Expense'].mean()
# Out:
# np.float64(18818.0)

# %%
inc_data['Mthly_HH_Expense'].median()
# Out:
# 15500.0

# %%
inc_data['Mthly_HH_Expense'].mode()
# Out:
# 0    25000
# Name: Mthly_HH_Expense, dtype: int64

# %%
mth_exp_tmp = pd.crosstab(index=inc_data['Mthly_HH_Expense'], columns = 'count')
mth_exp_tmp.reset_index(inplace=True)
mth_exp_tmp[mth_exp_tmp['count']== inc_data.Mthly_HH_Expense.value_counts().max()]
# Out:
# col_0  Mthly_HH_Expense  count
# 18                25000      8

# %%
inc_data.columns
# Out:
# Index(['Mthly_HH_Income', 'Mthly_HH_Expense', 'No_of_Fly_Members',
#        'Emi_or_Rent_Amt', 'Annual_HH_Income', 'Highest_Qualified_Member',
#        'No_of_Earning_Members'],
#       dtype='object')

# %%
inc_data['Highest_Qualified_Member'].value_counts().plot(kind='bar')
plt.show()

# %%
inc_data.plot(x = 'Mthly_HH_Income', y = 'Mthly_HH_Expense')
# Out:
# <Axes: xlabel='Mthly_HH_Income'>

# %%
plt.show()

# %%
IQR = inc_data['Mthly_HH_Expense'].quantile(0.75) - inc_data['Mthly_HH_Expense'].quantile(0.25)
IQR
# Out:
# np.float64(15000.0)

# %%
inc_data['Mthly_HH_Expense'].var()
# Out:
# 146173342.85714287

# %%
pd.DataFrame({'variance': [inc_data.iloc[:, 0].var()]}).T
# Out:
#                      0
# variance  6.811009e+08

# %%
inc_data['Mthly_HH_Expense'].std()
# Out:
# 12090.216824240286

# %%
std_value = inc_data.iloc[:, 0].std()
pd.DataFrame({'std': [std_value]})
# Out:
#             std
# 0  26097.908979

# %%
coef = inc_data['Mthly_HH_Expense'].std() / inc_data['Mthly_HH_Expense'].mean()
coef
# Out:
# np.float64(0.6424814977277227)

# %%
coef
# Out:
# np.float64(0.6424814977277227)

# %%
inc_data["Highest_Qualified_Member"].value_counts().to_frame().T
# Out:
# Highest_Qualified_Member  Graduate  Under-Graduate  Professional  \
# count                           19              10            10
#
# Highest_Qualified_Member  Post-Graduate  Illiterate
# count                                 6           5

# %%
inc_data["No_of_Earning_Members"].value_counts().plot(kind="bar", color='y')
# Out:
# <Axes: xlabel='No_of_Earning_Members'>

# %%
plt.show()

# %%
coeff_of_var_StockA = 10/15
print(coeff_of_var_StockA)

coeff_of_var_StockB = 5/10
print(coeff_of_var_StockB)
# Out:
# 0.6666666666666666
# 0.5
