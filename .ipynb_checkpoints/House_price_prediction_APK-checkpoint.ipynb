# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import pickle

import ipywidgets as widgets
from IPython.display import display

# %%
upload = widgets.FileUpload(accept=r"C:\Users\mayur\Downloads\archive (10)\data.csv", multiple=False)
display(upload)
# Out:
# FileUpload(value=(), accept='C:\\Users\\mayur\\Downloads\\archive (10)\\data.csv', description='Upload')

# %%
def load_csv(change):
    global df
    content = list(upload.value.values())[0]['content']
    df = pd.read_csv(pd.io.common.BytesIO(content))
    display(df.head())

upload.observe(load_csv, names='value')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Area       5 non-null      int64
#  1   Bedrooms   5 non-null      int64
#  2   Bathrooms  5 non-null      int64
#  3   Price      5 non-null      int64
# dtypes: int64(4)
# memory usage: 292.0 bytes

# %%
df.describe()
# Out:
#               Area  Bedrooms  Bathrooms       Price
# count     5.000000   5.00000    5.00000    5.000000
# mean   2000.000000   3.20000    2.20000   83.000000
# std     790.569415   0.83666    0.83666   27.748874
# min    1000.000000   2.00000    1.00000   50.000000
# 25%    1500.000000   3.00000    2.00000   65.000000
# 50%    2000.000000   3.00000    2.00000   80.000000
# 75%    2500.000000   4.00000    3.00000  100.000000
# max    3000.000000   4.00000    3.00000  120.000000

# %%
target = df.columns[-1]

plt.hist(df[target], bins=20)
plt.title(f"{target} Distribution")
plt.xlabel(target)
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
print(df.columns.tolist())
# Out:
# ['Area', 'Bedrooms', 'Bathrooms', 'Price']

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X, y)

print("✅ Model trained successfully")
# Out:
# ✅ Model trained successfully

# %%
with open("mlr_model.pkl", "wb") as f:
    pickle.dump(model, f)

print("✅ Model saved as mlr_model.pkl")
# Out:
# ✅ Model saved as mlr_model.pkl

# %%
sliders = {}
for col in X.columns:
    sliders[col] = widgets.FloatSlider(
        min=float(df[col].min()),
        max=float(df[col].max()),
        step=1,
        description=col
    )
    display(sliders[col])
# Out:
# FloatSlider(value=1000.0, description='Area', max=3000.0, min=1000.0, step=1.0)
# FloatSlider(value=2.0, description='Bedrooms', max=4.0, min=2.0, step=1.0)
# FloatSlider(value=1.0, description='Bathrooms', max=3.0, min=1.0, step=1.0)

# %%
def predict(b):
    input_data = np.array([[sliders[col].value for col in X.columns]])
    pred = model.predict(input_data)
    
    print(f"🏷️ Predicted Price: ₹ {pred[0]:.2f}")
    
    # Prediction graph
    plt.scatter(y, model.predict(X))
    plt.xlabel("Actual Price")
    plt.ylabel("Predicted Price")
    plt.title("Prediction Graph")
    plt.show()

btn = widgets.Button(description="Predict Price")
btn.on_click(predict)
display(btn)
# Out:
# Button(description='Predict Price', style=ButtonStyle())

# %%
 # !pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# Collecting numpy<2.3.0,>=2 (from opencv-python)
#   Downloading numpy-2.2.6-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
# Downloading numpy-2.2.6-cp313-cp313-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    -------- ------------------------------- 2.6/12.6 MB 16.6 MB/s eta 0:00:01
#    ------------ --------------------------- 3.9/12.6 MB 10.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.9/12.6 MB 15.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 16.2 MB/s  0:00:00
# Installing collected packages: numpy, opencv-python
#
#   Attempting uninstall: numpy
#
#     Found existing installation: numpy 2.3.5
#
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#     Uninstalling numpy-2.3.5:
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#       Successfully uninstalled numpy-2.3.5
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    -------------------- ------------------- 1/2 [opencv-python]
#    -------------------- ------------------- 1/2 [opencv-python]
#    -------------------- ------------------- 1/2 [opencv-python]
#    -------------------- ------------------- 1/2 [opencv-python]
#    ---------------------------------------- 2/2 [opencv-python]
#
# Successfully installed numpy-2.2.6 opencv-python-4.12.0.88
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\mayur\AppData\Local\Temp\pip-uninstall-2n3sj_8x'.
#   You can safely remove it manually.

# %%
import cv2
from PIL import Image
from io import BytesIO

img_upload = widgets.FileUpload(accept='image/*', multiple=False)
display(img_upload)
# Out:
# FileUpload(value=(), accept='image/*', description='Upload')

# %%
def process_image(change):
    img_bytes = list(img_upload.value.values())[0]['content']
    img = Image.open(BytesIO(img_bytes))
    
    img = np.array(img)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    resized = cv2.resize(gray, (128,128))
    
    plt.imshow(resized, cmap='gray')
    plt.title("Preprocessed Image")
    plt.axis("off")
    plt.show()

img_upload.observe(process_image, names='value')
