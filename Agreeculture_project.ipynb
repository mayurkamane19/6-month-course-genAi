# %%
# !pip install missingno
# Out:
# Collecting missingno
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: numpy in c:\users\mayur\anaconda3\lib\site-packages (from missingno) (2.1.3)
# Requirement already satisfied: matplotlib in c:\users\mayur\anaconda3\lib\site-packages (from missingno) (3.10.7)
# Requirement already satisfied: scipy in c:\users\mayur\anaconda3\lib\site-packages (from missingno) (1.15.3)
# Requirement already satisfied: seaborn in c:\users\mayur\anaconda3\lib\site-packages (from missingno) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mayur\anaconda3\lib\site-packages (from matplotlib->missingno) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\mayur\anaconda3\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mayur\anaconda3\lib\site-packages (from matplotlib->missingno) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\mayur\anaconda3\lib\site-packages (from matplotlib->missingno) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\mayur\anaconda3\lib\site-packages (from matplotlib->missingno) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\mayur\anaconda3\lib\site-packages (from matplotlib->missingno) (11.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\mayur\anaconda3\lib\site-packages (from matplotlib->missingno) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mayur\anaconda3\lib\site-packages (from matplotlib->missingno) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\mayur\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.17.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\mayur\anaconda3\lib\site-packages (from seaborn->missingno) (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mayur\anaconda3\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mayur\anaconda3\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2025.2)
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Installing collected packages: missingno
# Successfully installed missingno-0.5.2

# %%
# Import all of the necessary packages.
import numpy as np
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns
import re
from matplotlib.pyplot import stackplot

# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"C:\Users\mayur\Downloads\archive (4)\Agriculture.csv")

# %%
df.head()
# Out:
#                  NGA                     Variable    Value From Value To  \
# 0  Big Island Hawaii        Carbohydrate Source 1  sweet potato      NaN
# 1  Big Island Hawaii              Cropping System       swidden      NaN
# 2  Big Island Hawaii  Cropping System Coefficient          0.23      NaN
# 3  Big Island Hawaii       Fertilizer Coefficient           1.3      NaN
# 4  Big Island Hawaii                  Fertilizers       present      NaN
#
#   Value Note  Date From  Date To Unit  \
# 0        NaN        750     1800  NaN
# 1        NaN        750     1400  NaN
# 2   inferred        750     1400  NaN
# 3        NaN        750     1900  NaN
# 4   inferred        750     1800  NaN
#
#                                          Explanation
# 0  Sweet potato was the the dominant crop in the ...
# 1  Shifting cultivation (in the form of swidden a...
# 2                                   Generic estimate
# 3         Assuming 30% while looking for an estimate
# 4  Inferred ash from slash-and-burn cultivation. ...

# %%
df.columns
# Out:
# Index(['NGA', 'Variable', 'Value From', 'Value To', 'Value Note', 'Date From',
#        'Date To', 'Unit', 'Explanation'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330 entries, 0 to 329
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   NGA          330 non-null    object
#  1   Variable     330 non-null    object
#  2   Value From   330 non-null    object
#  3   Value To     53 non-null     object
#  4   Value Note   36 non-null     object
#  5   Date From    330 non-null    int64
#  6   Date To      330 non-null    int64
#  7   Unit         61 non-null     object
#  8   Explanation  330 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 23.3+ KB

# %%
fig, axarr = plt.subplots(1, 2, figsize=(20, 10))

df.dtypes.value_counts().plot.pie(explode=[0.1,0.1],autopct='%1.1f%%',shadow=True,ax=axarr[1])
axarr[1].set_title("type of our data ", fontsize=18)

df.dtypes.value_counts().plot(kind='bar',ax=axarr[0], color = 'yellow')
plt.title('type of our data', fontsize = 18);
axarr[0].set_title("type of our data ", fontsize=18)
# Out:
# Text(0.5, 1.0, 'type of our data ')

# %%
df.shape
# Out:
# (330, 9)

# %%
df.isnull().sum()
# Out:
# NGA              0
# Variable         0
# Value From       0
# Value To       277
# Value Note     294
# Date From        0
# Date To          0
# Unit           269
# Explanation      0
# dtype: int64

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
color = ['grey','grey','grey','grey','grey','grey','yellow', 'yellow', 'yellow']
msno.bar(df,fontsize =16, color = color, sort = 'descending', figsize = (12,6))
# Out:
# <Axes: >

# %%
msno.dendrogram(df)
# Out:
# <Axes: >

# %%
for i in df.columns:
    null_rate = df[i].isnull().sum() / len(df) * 100 
    if null_rate > 0 :
        print("{}'s null rate :{}%".format(i,round(null_rate,2)))
# Out:
# Value To's null rate :83.94%
# Value Note's null rate :89.09%
# Unit's null rate :81.52%

# %%
df.NGA.value_counts()
# Out:
# NGA
# Latium                        24
# Paris Basin                   23
# Valley of Oaxaca              20
# Middle Yellow River Valley    19
# Kansai                        17
# Konya Plain                   16
# Kachi Plain                   15
# Cambodian Basin               15
# Cuzco                         14
# Susiana                       12
# Big Island Hawaii             12
# Deccan                        12
# Upper Egypt                   11
# Cahokia                       10
# Central Java                  10
# Niger Inland Delta            10
# Yemeni Coastal Plain           9
# Chuuk Islands                  9
# Finger Lakes                   9
# Sogdiana                       8
# Lena River Valley              7
# North Colombia                 7
# Southern China Hills           6
# Kapuasi Basin                  6
# Garo Hills                     6
# Ghanaian Coast                 6
# Oro PNG                        6
# Iceland                        5
# Lowland Andes                  5
# Orkhon Valley                  1
# Name: count, dtype: int64

# %%
df['Variable'].value_counts()
# Out:
# Variable
# Historical Productivity        62
# Cropping System                55
# Cropping System Coefficient    54
# Irrigation                     40
# Fertilizers                    40
# Carbohydrate Source 1          36
# Fertilizer Coefficient         26
# Irrigation Coefficient         16
# HIstorical Productivity         1
# Name: count, dtype: int64

# %%
df['Variable'].replace(to_replace='HIstorical Productivity', value = 'Historical Productivity', inplace=True)

# %%
df['Variable'].value_counts()
# Out:
# Variable
# Historical Productivity        63
# Cropping System                55
# Cropping System Coefficient    54
# Fertilizers                    40
# Irrigation                     40
# Carbohydrate Source 1          36
# Fertilizer Coefficient         26
# Irrigation Coefficient         16
# Name: count, dtype: int64

# %%
df=df.fillna(0)

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#           Date From      Date To
# count    330.000000   330.000000
# mean   -1536.809091  1059.727273
# std     2867.255946  1447.224197
# min   -10000.000000 -7000.000000
# 25%    -3000.000000   710.000000
# 50%     -800.000000  1810.000000
# 75%      930.000000  1914.250000
# max     2000.000000  2001.000000

# %%
plt.figure(figsize=(20,10))
sns.lineplot(data=df, y="Date From",x='NGA', color='green')
plt.xticks(rotation=90)
plt.title('Relation betwwen time and NGA', fontsize=18, fontweight = "bold")
# Out:
# Text(0.5, 1.0, 'Relation betwwen time and NGA')

# %%
my_colors=['lightblue','lightgreen',
           'silver','orange','pink']
plt.figure(figsize=(15,15))
df.NGA.value_counts().plot.pie(autopct='%1.1f%%',shadow=True, colors = my_colors)
plt.title("Counts of NGA", fontsize=18)
# Out:
# Text(0.5, 1.0, 'Counts of NGA')

# %%
df.NGA.nunique()
# Out:
# 30

# %%
sns.set_palette("plasma")
df.plot(subplots=True, figsize=(20,15))
plt.legend(fontsize=16)
plt.show()

# %%
plt.figure(figsize=(30,30))
g = sns.catplot(x="NGA", y="Date To", kind="box",
            data=df.sort_values("NGA"), palette="tab10")
g.fig.set_figwidth(15)
g.fig.set_figheight(8)
plt.title('NGA vs Date To',fontsize=15, fontweight='bold')
plt.xticks(rotation=90, fontsize=14)
plt.show()

# %%
plt.figure(figsize=(30,30))
g = sns.catplot(x="Variable", y="Date From", kind="boxen",
            data=df.sort_values("NGA"), palette="tab10")
g.fig.set_figwidth(12)
g.fig.set_figheight(8)
plt.title('NGA vs Date From',fontsize=15, fontweight='bold')
plt.xticks(rotation=90, fontsize=14)
plt.show()

# %%
sns.set_palette("rainbow")
plt.figure(figsize=(15, 10))
sns.set_context("notebook",font_scale=1)
sns.kdeplot(data=df, x="Date To", hue="NGA",
    cumulative=True, common_norm=False, common_grid=True,
)
plt.title('Date To vs NGA',fontsize=15, fontweight='bold')

plt.show()

# %%
df_yield = df[(df.Unit == 't/ha')]

# %%
df_yield
# Out:
#                    NGA                 Variable Value From Value To  \
# 8    Big Island Hawaii  Historical Productivity       3.25        0
# 21             Cahokia  Historical Productivity      0.672    1.681
# 33     Cambodian Basin  Historical Productivity       1.46        0
# 36     Cambodian Basin  Historical Productivity        2.5        0
# 46        Central Java  Historical Productivity      1.345    1.681
# ..                 ...                      ...        ...      ...
# 316   Valley of Oaxaca  Historical Productivity        0.7        1
# 317   Valley of Oaxaca  Historical Productivity        0.8      1.1
# 318   Valley of Oaxaca  Historical Productivity          1      1.4
# 319   Valley of Oaxaca  Historical Productivity        1.1      1.5
# 320   Valley of Oaxaca  Historical Productivity        1.4      1.9
#
#     Value Note  Date From  Date To  Unit  \
# 8            0       1400     1800  t/ha
# 21           0        800     1500  t/ha
# 33           0       1080     1327  t/ha
# 36           0       1900     2000  t/ha
# 46           0       1568     1703  t/ha
# ..         ...        ...      ...   ...
# 316          0       -100      200  t/ha
# 317          0        100      500  t/ha
# 318          0        500      700  t/ha
# 319          0        700      900  t/ha
# 320          0        900     1520  t/ha
#
#                                            Explanation
# 8    This figure was derived from the mean yield fo...
# 21   "Native maize yields were inherently low and u...
# 33   "Acker has given detailed consideration to the...
# 36   An average household is composed of five to si...
# 46   "Even under considerable variation in growing ...
# ..                                                 ...
# 316                        Kowalewski 1980 (see above)
# 317                        Kowalewski 1980 (see above)
# 318  The estimates for the highest quality land (Cl...
# 319                        Kowalewski 1980 (see above)
# 320                        Kowalewski 1980 (see above)
#
# [61 rows x 9 columns]

# %%
df_yield['NGA'].value_counts()
# Out:
# NGA
# Latium                        11
# Paris Basin                   11
# Valley of Oaxaca               7
# Upper Egypt                    6
# Middle Yellow River Valley     6
# Kansai                         6
# Chuuk Islands                  2
# Cambodian Basin                2
# Cahokia                        1
# Big Island Hawaii              1
# Kachi Plain                    1
# Finger Lakes                   1
# Deccan                         1
# Cuzco                          1
# Central Java                   1
# Konya Plain                    1
# Oro PNG                        1
# Sogdiana                       1
# Name: count, dtype: int64

# %%
df_yield['Variable'].unique()
# Out:
# array(['Historical Productivity'], dtype=object)

# %%
df_yield['Value From'].unique()
# Out:
# array(['3.25', '0.672', '1.46', '2.5', '1.345', '16', '10', '1.2',
#        '1.371', '0.5', '1.096', '1.3', '1.55', '1.5', '1.9', '2.1', '2.2',
#        '1', '0.376', '1.296', '1.35', '0.54', '0.23', '0.675', '0.878',
#        '0.405', '0.258', '1.05', '0.75', '0.8', '0.25', '6.5', '0.65',
#        '0.308', '0.773', '1.624', '1.16', '1.933', '2.22', '0.62', '1.07',
#        '1.71', '1.425', '1.665', '1.075', '0.6', '0.7', '1.1', '1.4'],
#       dtype=object)

# %%
df_yield[['Value From', 'Value To']] = df_yield[['Value From', 'Value To']].apply(pd.to_numeric)
df_yield.dtypes
# Out:
# NGA             object
# Variable        object
# Value From     float64
# Value To       float64
# Value Note      object
# Date From        int64
# Date To          int64
# Unit            object
# Explanation     object
# dtype: object

# %%
plt.figure(figsize=(20,10))
sns.lineplot(data=df_yield, y="Value From",x='Date From', palette='viridis', hue = 'NGA')
plt.xticks(rotation=90, fontsize=16)
plt.title('Relation betwwen Productivity and NGA across Time', fontsize=16, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Relation betwwen Productivity and NGA across Time')

# %%
plt.figure(figsize=(20,10))
sns.lineplot(data=df_yield, y="Value To",x='NGA', color='darkgreen')
plt.xticks(rotation=90, fontsize=16)
plt.yticks(fontsize=16)
plt.title('Relation betwwen Productivity and NGA - (Value To)', fontsize=16, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Relation betwwen Productivity and NGA - (Value To)')

# %%
df_carb_source = df[(df.Variable == 'Carbohydrate Source 1')]

# %%
df_carb_source.head(10)
# Out:
#                   NGA               Variable    Value From Value To  \
# 0   Big Island Hawaii  Carbohydrate Source 1  sweet potato        0
# 12            Cahokia  Carbohydrate Source 1      chenopod        0
# 18            Cahokia  Carbohydrate Source 1         maize        0
# 22    Cambodian Basin  Carbohydrate Source 1          rice        0
# 23    Cambodian Basin  Carbohydrate Source 1          rice        0
# 37       Central Java  Carbohydrate Source 1          rice        0
# 49      Chuuk Islands  Carbohydrate Source 1    breadfruit        0
# 56              Cuzco  Carbohydrate Source 1         maize        0
# 70             Deccan  Carbohydrate Source 1        millet        0
# 76             Deccan  Carbohydrate Source 1          rice        0
#
#    Value Note  Date From  Date To Unit  \
# 0           0        750     1800    0
# 12          0      -1800      800    0
# 18          0        800     1500    0
# 22          0      -2500    -1000    0
# 23          0      -1000     1932    0
# 37          0      -4000     1703    0
# 49          0       1300     1900    0
# 56   inferred      -5000     1520    0
# 70          0      -2700    -1200    0
# 76          0      -1200     1900    0
#
#                                           Explanation
# 0   Sweet potato was the the dominant crop in the ...
# 12                             Smith and Yarnell 2009
# 18                                     Need reference
# 22  Bellwood (2005) dates the beginning of the Neo...
# 23  "The staples of their diet were rice and fish,...
# 37  "Recent genetic work tells us that rice, Oryza...
# 49  "In Chuuk the subsistence base of the earliest...
# 56  While the Lake Marcacohca pollen cores can ind...
# 70  2700-1200 BCE: "Cattle and caprine pastoralism...
# 76  "With the expansion in irrigation, rice cultiv...

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=90, fontsize=16)
sns.lineplot(x='NGA', y='Date From', data=df_carb_source)
plt.title('Relation between Date From and NGA', fontsize=16, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Relation between Date From and NGA')

# %%
plt.figure(figsize=(20,20))
g = sns.catplot(data=df_carb_source, y="Value From",x='NGA', color='red')
plt.xticks(rotation=90, fontsize=16)
g.fig.set_figwidth(20)
g.fig.set_figheight(8)
plt.yticks(fontsize=16)
plt.title('Relation between Type of Carbohydrate and NGA', fontsize=16, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Relation between Type of Carbohydrate and NGA')

# %%
plt.figure(figsize=(20,10))
sns.countplot(data=df_carb_source, x="Value From", palette='rainbow')
plt.xticks(fontsize=14)
plt.title('Count of Different Carbohydrate Sources across NGAs', fontsize=18, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Count of Different Carbohydrate Sources across NGAs')

# %%
df_irrigation = df[(df.Variable == 'Irrigation Coefficient')]
df_irrigation.head(5)
df_irrigation[['Value From', 'Value To']] = df_irrigation[['Value From', 'Value To']].apply(pd.to_numeric)

# %%
plt.figure(figsize=(20,15))
sns.barplot(data=df_irrigation, x="NGA", y="Value From", palette="viridis")
plt.xticks(fontsize=15, rotation = 90)
plt.yticks(fontsize=15)
plt.title('Coefficient of Irrigation across NGAs', fontsize=18, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Coefficient of Irrigation across NGAs')

# %%
df_fertilizer = df[(df.Variable == 'Fertilizer Coefficient')]
df_fertilizer.head(5)
df_fertilizer[['Value From', 'Value To']] = df_fertilizer[['Value From', 'Value To']].apply(pd.to_numeric)

# %%
plt.figure(figsize=(20,15))
sns.barplot(data=df_fertilizer, x="NGA", y="Value From", palette="terrain")
plt.xticks(fontsize=15, rotation = 90)
plt.yticks(fontsize=15)
plt.title('Coefficient of Fertilizer across NGAs', fontsize=18, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Coefficient of Fertilizer across NGAs')
