# %%
import gradio as gr

# %%
gr.close_all()

def add_numbers(a, b):
    return a + b

interface = gr.Interface(
    fn=add_numbers,
    inputs=[
        gr.Number(label="First Number"),
        gr.Number(label="Second Number")
    ],
    outputs=gr.Number(label="Sum"),
    title="Addition Calculator",
    description="Enter two numbers and get their sum.",
    examples=None,
)

interface.launch()

with interface:
    gr.Image(value="banner.png", show_label=False)
# Out:
# Closing server running on port: 7860
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr

# %%
# jupyter refresh issue fix
gr.close_all()
# Out:
# Closing server running on port: 7860

# %%
with gr.Blocks(title="Colorful Mickey Banner") as demo:
    gr.Image(r"C:\Users\mayur\Downloads\Mickey 1.jpg", show_label=False, height=250)

    gr.Markdown("## 🎨 Colorful Banner + Calculator")

    a = gr.Number(label="First Number")
    b = gr.Number(label="Second Number")
    out = gr.Number(label="Sum")

    gr.Button("Calculate").click(add_numbers, [a, b], out)

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr
gr.close_all()
# Out:
# Closing server running on port: 7860

# %%
def add_numbers(a, b):
    return a + b

# %%
with gr.Blocks(title="3D Cartoon Mouse Calculator") as demo:
    gr.Image(r"C:\Users\mayur\Downloads\Mickey2.jpg", show_label=False, height=260)

    gr.Markdown("## 🐭 3D Cartoon Mouse Calculator")

    x = gr.Number(label="First Number")
    y = gr.Number(label="Second Number")
    result = gr.Number(label="Sum")

    gr.Button("Add Numbers").click(add_numbers, [x, y], result)

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr
gr.close_all()
# Out:
# Closing server running on port: 7860

# %%
def add_numbers(a, b):
    return a + b

# %%
with gr.Blocks(title="Emoji Mouse Calculator") as demo:
    gr.Image(r"C:\Users\mayur\Downloads\mouse.gif", show_label=False, height=200)

    gr.Markdown("## 😀 Emoji Mouse Calculator")

    n1 = gr.Number(label="Enter First Number")
    n2 = gr.Number(label="Enter Second Number")
    output = gr.Number(label="Result")

    gr.Button("Calculate ✔️").click(add_numbers, [n1, n2], output)

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
