# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import pandas as pd

dataset = pd.read_csv(
    r"C:\Users\mayur\Downloads\2.LOGISTIC REGRESSION CODE\2.LOGISTIC REGRESSION CODE\final1.csv"
)

dataset.head()
# Out:
#    Unnamed: 0   User ID  Gender  Age  EstimatedSalary
# 0           0  15724611    Male   45            60000
# 1           1  15725621  Female   79            64000
# 2           2  15725622    Male   23            78000
# 3           3  15720611  Female   34            45000
# 4           4  15588044    Male   29            76000

# %%
X = dataset.iloc[:, [2, 3]].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test  = sc.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 4
#       1 from sklearn.preprocessing import StandardScaler
#       3 sc = StandardScaler()
# ----> 4 X_train = sc.fit_transform(X_train)
#       5 X_test  = sc.transform(X_test)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# ...

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 from sklearn.linear_model import LogisticRegression
#       2 classifier = LogisticRegression()
# ----> 3 classifier.fit(X_train, y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1247, in LogisticRegression.fit(self, X, y, sample_weight)
#    1244 else:
#    1245     _dtype = [np.float64, np.float32]
# -> 1247 X, y = validate_data(
#    1248     self,
# ...

# %%
y_pred = classifier.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 y_pred = classifier.predict(X_test)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:375, in LinearClassifierMixin.predict(self, X)
#     361 """
#     362 Predict class labels for samples in X.
#     363
#    (...)    372     Vector containing the class labels for each sample.
#     373 """
#     374 xp, _ = get_namespace(X)
# --> 375 scores = self.decision_function(X)
#     376 if len(scores.shape) == 1:
#     377     indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:349, in LinearClassifierMixin.decision_function(self, X)
#     330 def decision_function(self, X):
#     331     """
#     332     Predict confidence scores for samples.
#     333
#    (...)    347         this class would be predicted.
# ...

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 from sklearn.metrics import confusion_matrix
# ----> 2 cm = confusion_matrix(y_test, y_pred)
#       3 print(cm)
#
# NameError: name 'y_pred' is not defined

# %%
from sklearn.metrics import accuracy_score 
ac = accuracy_score(y_test, y_pred)
print(ac)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 from sklearn.metrics import accuracy_score
# ----> 2 ac = accuracy_score(y_test, y_pred)
#       3 print(ac)
#
# NameError: name 'y_pred' is not defined

# %%
from sklearn.metrics import classification_report
cr = classification_report(y_test, y_pred)
cr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 from sklearn.metrics import classification_report
# ----> 2 cr = classification_report(y_test, y_pred)
#       3 cr
#
# NameError: name 'y_pred' is not defined

# %%
bias = classifier.score(X_train, y_train)
bias
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 bias = classifier.score(X_train, y_train)
#       2 bias
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:548, in ClassifierMixin.score(self, X, y, sample_weight)
#     523 """
#     524 Return :ref:`accuracy <accuracy_score>` on provided data and labels.
#     525
#    (...)    544     Mean accuracy of ``self.predict(X)`` w.r.t. `y`.
#     545 """
#     546 from .metrics import accuracy_score
# --> 548 return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:375, in LinearClassifierMixin.predict(self, X)
#     361 """
#     362 Predict class labels for samples in X.
#     363
#    (...)    372     Vector containing the class labels for each sample.
#     373 """
#     374 xp, _ = get_namespace(X)
# ...

# %%
variance = classifier.score(X_test, y_test)
variance
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 variance = classifier.score(X_test, y_test)
#       2 variance
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:548, in ClassifierMixin.score(self, X, y, sample_weight)
#     523 """
#     524 Return :ref:`accuracy <accuracy_score>` on provided data and labels.
#     525
#    (...)    544     Mean accuracy of ``self.predict(X)`` w.r.t. `y`.
#     545 """
#     546 from .metrics import accuracy_score
# --> 548 return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:375, in LinearClassifierMixin.predict(self, X)
#     361 """
#     362 Predict class labels for samples in X.
#     363
#    (...)    372     Vector containing the class labels for each sample.
#     373 """
#     374 xp, _ = get_namespace(X)
# ...

# %%
from matplotlib.colors import ListedColormap
X_set, y_set = X_train, y_train
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 from matplotlib.colors import ListedColormap
#       2 X_set, y_set = X_train, y_train
# ----> 3 X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
#       4                      np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
#       5 plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
#       6              alpha = 0.75, cmap = ListedColormap(('red', 'green')))
#       7 plt.xlim(X1.min(), X1.max())
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('Logistic Regression (Training set)')
plt.xlabel('Age')
plt.ylabel('Estimated Salary')
plt.legend()
plt.show()
# Out:
# C:\Users\mayur\AppData\Local\Temp\ipykernel_18644\4191954083.py:2: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],

# %%
from matplotlib.colors import ListedColormap
X_set, y_set = X_test, y_test
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 from matplotlib.colors import ListedColormap
#       2 X_set, y_set = X_test, y_test
# ----> 3 X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
#       4                      np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
#       5 plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
#       6              alpha = 0.75, cmap = ListedColormap(('red', 'green')))
#       7 plt.xlim(X1.min(), X1.max())
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('Logistic Regression (Test set)')
plt.xlabel('Age')
plt.ylabel('Estimated Salary')
plt.legend()
plt.show()
# Out:
# C:\Users\mayur\AppData\Local\Temp\ipykernel_18644\1249040523.py:2: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],

# %%
# ===============================
# IMPORT LIBRARIES
# ===============================
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# ===============================
# LOAD DATASET
# ===============================
dataset = pd.read_csv(
    r"C:\Users\mayur\Downloads\2.LOGISTIC REGRESSION CODE\2.LOGISTIC REGRESSION CODE\final1.csv"
)

# ===============================
# FEATURES & TARGET
# (Age, EstimatedSalary → Purchased)
# ===============================
X = dataset.iloc[:, [2, 3]].values
y = dataset.iloc[:, -1].values

# ===============================
# TRAIN TEST SPLIT
# ===============================
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=0
)

# ===============================
# FEATURE SCALING
# ===============================
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test  = sc.transform(X_test)

# ===============================
# LOGISTIC REGRESSION MODEL
# ===============================
from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression(random_state=0)
classifier.fit(X_train, y_train)

# ===============================
# PREDICTION
# ===============================
y_pred = classifier.predict(X_test)

# ===============================
# EVALUATION
# ===============================
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nAccuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

print("Training Accuracy (Bias):", classifier.score(X_train, y_train))
print("Testing Accuracy (Variance):", classifier.score(X_test, y_test))

# ===============================
# FUTURE DATA PREDICTION
# ===============================
# Example: Age = 35, Salary = 65000
future_data = [[35, 65000]]

future_data_scaled = sc.transform(future_data)
future_prediction = classifier.predict(future_data_scaled)

print("\nFuture Prediction:")
if future_prediction[0] == 1:
    print("✅ Customer WILL buy the product")
else:
    print("❌ Customer will NOT buy the product")

# ===============================
# VISUALIZATION - TRAINING SET
# ===============================
from matplotlib.colors import ListedColormap

X_set, y_set = X_train, y_train
X1, X2 = np.meshgrid(
    np.arange(X_set[:, 0].min()-1, X_set[:, 0].max()+1, 0.01),
    np.arange(X_set[:, 1].min()-1, X_set[:, 1].max()+1, 0.01)
)

plt.contourf(
    X1, X2,
    classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
    alpha=0.75,
    cmap=ListedColormap(('red', 'green'))
)

for i, j in enumerate(np.unique(y_set)):
    plt.scatter(
        X_set[y_set == j, 0],
        X_set[y_set == j, 1],
        c=ListedColormap(('red', 'green'))(i),
        label=j
    )

plt.title("Logistic Regression (Training Set)")
plt.xlabel("Age")
plt.ylabel("Estimated Salary")
plt.legend()
plt.show()

# ===============================
# VISUALIZATION - TEST SET
# ===============================
X_set, y_set = X_test, y_test
X1, X2 = np.meshgrid(
    np.arange(X_set[:, 0].min()-1, X_set[:, 0].max()+1, 0.01),
    np.arange(X_set[:, 1].min()-1, X_set[:, 1].max()+1, 0.01)
)

plt.contourf(
    X1, X2,
    classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
    alpha=0.75,
    cmap=ListedColormap(('red', 'green'))
)

for i, j in enumerate(np.unique(y_set)):
    plt.scatter(
        X_set[y_set == j, 0],
        X_set[y_set == j, 1],
        c=ListedColormap(('red', 'green'))(i),
        label=j
    )

plt.title("Logistic Regression (Test Set)")
plt.xlabel("Age")
plt.ylabel("Estimated Salary")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 37
#      34 from sklearn.preprocessing import StandardScaler
#      36 sc = StandardScaler()
# ---> 37 X_train = sc.fit_transform(X_train)
#      38 X_test  = sc.transform(X_test)
#      40 # ===============================
#      41 # LOGISTIC REGRESSION MODEL
#      42 # ===============================
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
# ...
